# %% [markdown]
# # Figuring out which systems are completely ready to be processed by script workflow
# ---
#
# Notebooks commonly broke because of trivial issues, like the files weren't downloaded locally or something like that

# %% [markdown]
# # Import Modules

# %%
import os
print(os.getcwd())
import sys
import time; ti = time.time()

import numpy as np

# #########################################################
from methods import get_df_jobs, get_df_atoms_sorted_ind
from methods import get_df_features_targets
from methods import get_df_features
# Out:
# /home/raulf2012/Dropbox/01_norskov/00_git_repos/PROJ_IrOx_OER/dft_workflow/job_analysis/systems_fully_ready

# %%
from methods import isnotebook    
isnotebook_i = isnotebook()
if isnotebook_i:
    from tqdm.notebook import tqdm
    verbose = True
else:
    from tqdm import tqdm
    verbose = False

# %%
df_jobs = get_df_jobs()
df_jobs_i = df_jobs

df_atoms_sorted_ind = get_df_atoms_sorted_ind()

# df_features_targets = get_df_features_targets()

df_features = get_df_features()

# %%
df_features[df_features["data"]["orig_slab_good"] == False]
# Out:
#                                                            data              \
#                                                     active_site ads att_num
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True           74.0  oh       1
#                                     3       True           74.0  oh       3
#                         76.0        1       True           76.0  oh       1
#                                     2       True           76.0  oh       2
#                                     3       True           76.0  oh       3
# ...                                                         ...  ..     ...
# slac    wonataro_02 oh  63.0        3       True           63.0  oh       3
#         wowukoli_59 oh  27.0        0       True           27.0  oh       0
#                                     1       True           27.0  oh       1
#                                     2       True           27.0  oh       2
#                                     3       True           27.0  oh       3
#
#                                                                      \
#                                                     compenv from_oh
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True      nersc    True
#                                     3       True      nersc    True
#                         76.0        1       True      nersc    True
#                                     2       True      nersc    True
#                                     3       True      nersc    True
# ...                                                     ...     ...
# slac    wonataro_02 oh  63.0        3       True       slac    True
#         wowukoli_59 oh  27.0        0       True       slac    True
#                                     1       True       slac    True
#                                     2       True       slac    True
#                                     3       True       slac    True
#
#                                                                                \
#                                                       job_id_max      slab_id
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True     wepewido_07  dakoputu_58
#                                     3       True     buvawasa_30  dakoputu_58
#                         76.0        1       True     vokuvige_58  dakoputu_58
#                                     2       True     ribumere_14  dakoputu_58
#                                     3       True     purevaga_05  dakoputu_58
# ...                                                          ...          ...
# slac    wonataro_02 oh  63.0        3       True     vakubipu_61  wonataro_02
#         wowukoli_59 oh  27.0        0       True     guserala_21  wowukoli_59
#                                     1       True     felimeho_71  wowukoli_59
#                                     2       True     lavogire_36  wowukoli_59
#                                     3       True     bokobitu_09  wowukoli_59
#
#                                                                       \
#                                                     active_site_orig
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True                  74
#                                     3       True                  74
#                         76.0        1       True                  76
#                                     2       True                  76
#                                     3       True                  76
# ...                                                              ...
# slac    wonataro_02 oh  63.0        3       True                  63
#         wowukoli_59 oh  27.0        0       True                  27
#                                     1       True                  27
#                                     2       True                  27
#                                     3       True                  27
#
#                                                                      \
#                                                     found_active_Ir
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True               True
#                                     3       True               True
#                         76.0        1       True               True
#                                     2       True               True
#                                     3       True               True
# ...                                                             ...
# slac    wonataro_02 oh  63.0        3       True               True
#         wowukoli_59 oh  27.0        0       True               True
#                                     1       True               True
#                                     2       True               True
#                                     3       True               True
#
#                                                                     ...  \
#                                                     num_missing_Os  ...
# compenv slab_id     ads active_site att_num from_oh                 ...
# nersc   dakoputu_58 oh  74.0        1       True               2.0  ...
#                                     3       True               0.0  ...
#                         76.0        1       True               0.0  ...
#                                     2       True               0.0  ...
#                                     3       True               0.0  ...
# ...                                                            ...  ...
# slac    wonataro_02 oh  63.0        3       True               0.0  ...
#         wowukoli_59 oh  27.0        0       True               0.0  ...
#                                     1       True               0.0  ...
#                                     2       True               0.0  ...
#                                     3       True               0.0  ...
#
#                                                               features  \
#                                                     magmom_active_site
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True                 0.062
#                                     3       True                 0.010
#                         76.0        1       True                -0.012
#                                     2       True                 0.005
#                                     3       True                -0.001
# ...                                                                ...
# slac    wonataro_02 oh  63.0        3       True                -0.007
#         wowukoli_59 oh  27.0        0       True                 0.001
#                                     1       True                -0.028
#                                     2       True                 0.001
#                                     3       True                -0.019
#
#                                                                          \
#                                                     active_o_metal_dist
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True               1.937609
#                                     3       True               1.902083
#                         76.0        1       True               1.927104
#                                     2       True               1.911381
#                                     3       True               1.906005
# ...                                                                 ...
# slac    wonataro_02 oh  63.0        3       True               1.949977
#         wowukoli_59 oh  27.0        0       True               1.909228
#                                     1       True               1.937022
#                                     2       True               1.908154
#                                     3       True               1.935593
#
#                                                                           \
#                                                     angle_O_Ir_surf_norm
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True               87.253357
#                                     3       True               85.900628
#                         76.0        1       True               60.545047
#                                     2       True               58.347694
#                                     3       True               57.371147
# ...                                                                  ...
# slac    wonataro_02 oh  63.0        3       True               66.539903
#         wowukoli_59 oh  27.0        0       True               53.992971
#                                     1       True               56.497839
#                                     2       True               53.980062
#                                     3       True               56.411728
#
#                                                                         \
#                                                     effective_ox_state
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True                   NaN
#                                     3       True              8.333333
#                         76.0        1       True              8.333333
#                                     2       True              8.333333
#                                     3       True              8.333333
# ...                                                                ...
# slac    wonataro_02 oh  63.0        3       True             10.000000
#         wowukoli_59 oh  27.0        0       True              8.000000
#                                     1       True              8.000000
#                                     2       True              8.000000
#                                     3       True              8.000000
#
#                                                                          \
#                                                     ir_o_mean  ir_o_std
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True          NaN       NaN
#                                     3       True     1.940913  0.150763
#                         76.0        1       True     1.954253  0.166545
#                                     2       True     1.947914  0.153582
#                                     3       True     1.949857  0.159527
# ...                                                       ...       ...
# slac    wonataro_02 oh  63.0        3       True     1.904587  0.160130
#         wowukoli_59 oh  27.0        0       True     1.992113  0.195295
#                                     1       True     1.977805  0.162448
#                                     2       True     1.990856  0.194604
#                                     3       True     1.978550  0.162758
#
#                                                                           \
#                                                       octa_vol   dH_bulk
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True           NaN -0.735138
#                                     3       True      9.397154 -0.735138
#                         76.0        1       True      9.647097 -0.735138
#                                     2       True      9.499022 -0.735138
#                                     3       True      9.517702 -0.735138
# ...                                                        ...       ...
# slac    wonataro_02 oh  63.0        3       True      8.710683 -0.599425
#         wowukoli_59 oh  27.0        0       True     10.256111 -0.691297
#                                     1       True     10.169214 -0.691297
#                                     2       True     10.224231 -0.691297
#                                     3       True     10.188347 -0.691297
#
#
#                                                      volume_pa bulk_oxid_state
# compenv slab_id     ads active_site att_num from_oh
# nersc   dakoputu_58 oh  74.0        1       True     11.952412               4
#                                     3       True     11.952412               4
#                         76.0        1       True     11.952412               4
#                                     2       True     11.952412               4
#                                     3       True     11.952412               4
# ...                                                        ...             ...
# slac    wonataro_02 oh  63.0        3       True     15.036089               6
#         wowukoli_59 oh  27.0        0       True     10.810322               4
#                                     1       True     10.810322               4
#                                     2       True     10.810322               4
#                                     3       True     10.810322               4
#
# [174 rows x 22 columns]

# %%
# #########################################################
print(20 * "# # ")
print("All done!")
print("Run time:", np.round((time.time() - ti) / 60, 3), "min")
print("sys_fully_ready.ipynb")
print(20 * "# # ")
# #########################################################
# Out:
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
# All done!
# Run time: 0.031 min
# sys_fully_ready.ipynb
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

# %%
# # #########################################################
# group_cols = ["compenv", "slab_id", "ads", "active_site", "att_num", ]
# grouped = df_jobs_i.groupby(group_cols)
# # #########################################################
# num_groups_processed = 0
# for i_cnt, (name_i, group_i) in enumerate(grouped):
#     tmp = 42

# %%
# group_i

# %%
# df_atoms_sorted_ind

# name_i

# %%
# df_features_targets["data"].columns

# df_features_targets
