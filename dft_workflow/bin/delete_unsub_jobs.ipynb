# %% [markdown]
# # Import Modules

# %%
import os
print(os.getcwd())
import sys

from pathlib import Path

import pandas as pd

from ase import io

# #########################################################
from dft_workflow_methods import get_path_rel_to_proj
from dft_workflow_methods import get_job_paths_info
from dft_workflow_methods import get_job_spec_dft_params, get_job_spec_scheduler_params
from dft_workflow_methods import submit_job
# Out:
# /home/raulf2012/Dropbox/01_norskov/00_git_repos/PROJ_IrOx_OER/dft_workflow/bin

# %% [markdown]
# # Script Inputs

# %%
root_dir = os.getcwd()

compenv = os.environ["COMPENV"]

if compenv == "wsl":
    root_dir = os.path.join(
        os.environ["PROJ_irox_oer_gdrive"],
        "dft_workflow")    
        # "dft_workflow/run_slabs/run_o_covered")    
        # "dft_workflow/run_slabs/run_o_covered/out_data.old/dft_jobs/slac")    


# slac_sub_queue = "suncat"  # 'suncat', 'suncat2', 'suncat3'

# %%
# print("sys.argv:", "\n", sys.argv)

print("")
print("sys.argv:")
tmp = [print(i) for i in sys.argv]
print("")
print("What is this one?", sys.argv[-1])
print("")


if sys.argv[-1] == "run":
    run_jobs = True
    print("running job isdjifjsiduf89usd089ufg089sady890gyasd9p8yf978asdy89fyasd89yf890asd7890f7890asd7f89sd")
else:
    run_jobs = False
# Out:
# sys.argv:
# /home/raulf2012/anaconda3/envs/PROJ_irox_oer/lib/python3.6/site-packages/ipykernel_launcher.py
# -f
# /home/raulf2012/.local/share/jupyter/runtime/kernel-febdab31-0590-473b-a034-b48cb70a9b93.json
#
# What is this one? /home/raulf2012/.local/share/jupyter/runtime/kernel-febdab31-0590-473b-a034-b48cb70a9b93.json

# %% [markdown]
# # Parse directories

# %%
from dft_workflow_methods import parse_job_dirs

df = parse_job_dirs(root_dir=root_dir)

# %%
def method(row_i):
    new_column_values_dict = {
        "compenv": None,
        }

    cand_clusters = []
    clusters_list = ["nersc", "sherlock", "slac", ]
    for i in row_i.path_job_root.split("/"):
        if i in clusters_list:
            cand_clusters.append(i)

    if len(cand_clusters) == 1:
        cluster_i = cand_clusters[0]
        new_column_values_dict["compenv"] = cluster_i
    else:
        print("Couldn't parse cluster from path")
        print(cand_clusters)

    # #####################################################
    for key, value in new_column_values_dict.items():
        row_i[key] = value
    return(row_i)

df_i = df
df_i = df_i.apply(
    method,
    axis=1)
df = df_i

# %%
from misc_modules.pandas_methods import reorder_df_columns

col_order = [
    "compenv",
    "is_submitted",
    "att_num",
    "rev_num",
    "is_rev_dir",
    "is_attempt_dir",

    "path_full",
    "path_rel_to_proj",
    "path_job_root",
    "path_job_root_w_att_rev",
    "path_job_root_w_att",
    "gdrive_path",
    ]
df = reorder_df_columns(col_order, df)

# %%
df_i = df
df_i = df_i[
    (df_i.is_submitted == False) & \
    [True for i in range(len(df_i))]
    ]

df_i
# Out:
#        compenv  is_submitted  att_num  rev_num  is_rev_dir  is_attempt_dir  \
# 280      nersc         False        1        2        True            True
# 282      nersc         False        2        2        True            True
# 951   sherlock         False        1        2        True            True
# 953   sherlock         False        1        2        True            True
# 962   sherlock         False        1        2        True            True
# 972   sherlock         False        1        2        True            True
# 976   sherlock         False        1        2        True            True
# 1014  sherlock         False        1        2        True            True
# 1022  sherlock         False        1        2        True            True
# 1031  sherlock         False        1        2        True            True
# 1043  sherlock         False        1        2        True            True
# 1049  sherlock         False        1        2        True            True
# 1073      slac         False        1        2        True            True
# 1111      slac         False        1        2        True            True
# 1113      slac         False        1        2        True            True
# 1115      slac         False        1        2        True            True
#
#                                               path_full path_rel_to_proj  \
# 280   /media/raulf2012/research_backup/PROJ_irox_oer...
# 282   /media/raulf2012/research_backup/PROJ_irox_oer...
# 951   /media/raulf2012/research_backup/PROJ_irox_oer...
# 953   /media/raulf2012/research_backup/PROJ_irox_oer...
# 962   /media/raulf2012/research_backup/PROJ_irox_oer...
# 972   /media/raulf2012/research_backup/PROJ_irox_oer...
# 976   /media/raulf2012/research_backup/PROJ_irox_oer...
# 1014  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1022  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1031  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1043  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1049  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1073  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1111  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1113  /media/raulf2012/research_backup/PROJ_irox_oer...
# 1115  /media/raulf2012/research_backup/PROJ_irox_oer...
#
#                                           path_job_root  \
# 280   dft_workflow/run_slabs/run_oh_covered/out_data...
# 282   dft_workflow/run_slabs/run_oh_covered/out_data...
# 951   dft_workflow/run_slabs/run_o_covered/out_data/...
# 953   dft_workflow/run_slabs/run_o_covered/out_data/...
# 962   dft_workflow/run_slabs/run_o_covered/out_data/...
# 972   dft_workflow/run_slabs/run_o_covered/out_data/...
# 976   dft_workflow/run_slabs/run_o_covered/out_data/...
# 1014  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1022  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1031  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1043  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1049  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1073  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1111  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1113  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1115  dft_workflow/run_slabs/run_o_covered/out_data/...
#
#                                 path_job_root_w_att_rev  \
# 280   dft_workflow/run_slabs/run_oh_covered/out_data...
# 282   dft_workflow/run_slabs/run_oh_covered/out_data...
# 951   dft_workflow/run_slabs/run_o_covered/out_data/...
# 953   dft_workflow/run_slabs/run_o_covered/out_data/...
# 962   dft_workflow/run_slabs/run_o_covered/out_data/...
# 972   dft_workflow/run_slabs/run_o_covered/out_data/...
# 976   dft_workflow/run_slabs/run_o_covered/out_data/...
# 1014  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1022  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1031  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1043  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1049  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1073  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1111  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1113  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1115  dft_workflow/run_slabs/run_o_covered/out_data/...
#
#                                     path_job_root_w_att  \
# 280   dft_workflow/run_slabs/run_oh_covered/out_data...
# 282   dft_workflow/run_slabs/run_oh_covered/out_data...
# 951   dft_workflow/run_slabs/run_o_covered/out_data/...
# 953   dft_workflow/run_slabs/run_o_covered/out_data/...
# 962   dft_workflow/run_slabs/run_o_covered/out_data/...
# 972   dft_workflow/run_slabs/run_o_covered/out_data/...
# 976   dft_workflow/run_slabs/run_o_covered/out_data/...
# 1014  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1022  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1031  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1043  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1049  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1073  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1111  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1113  dft_workflow/run_slabs/run_o_covered/out_data/...
# 1115  dft_workflow/run_slabs/run_o_covered/out_data/...
#
#                                             gdrive_path  is_empty
# 280   dft_workflow/run_slabs/run_oh_covered/out_data...     False
# 282   dft_workflow/run_slabs/run_oh_covered/out_data...     False
# 951   dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 953   dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 962   dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 972   dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 976   dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1014  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1022  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1031  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1043  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1049  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1073  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1111  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1113  dft_workflow/run_slabs/run_o_covered/out_data/...     False
# 1115  dft_workflow/run_slabs/run_o_covered/out_data/...     False

# %%
for i in df_i.path_full.tolist():
    print("rm -r " + i)
# Out:
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_oh_covered/out_data/dft_jobs/nersc/b5cgvsb16w/111/oh/active_site__71/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_oh_covered/out_data/dft_jobs/nersc/b5cgvsb16w/111/oh/active_site__71/02_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/7ic1vt7pz4/002/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/7ic1vt7pz4/110/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/8l919k6s7p/1-100/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/926dnunrxf/10-1/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/926dnunrxf/200/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/bpc2nk6qz1/111/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/mj7wbfb5nt/101/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/nu94n3v4n4/002/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/xlbfb49wml/1-101/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/sherlock/xw9y6rbkxr/2-1-112/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/slac/6pvt6r95ve/1-11/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/slac/8p937183bh/10-10/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/slac/8p937183bh/10-11/01_attempt/_02
# rm -r /media/raulf2012/research_backup/PROJ_irox_oer_gdrive/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/slac/8p937183bh/10-12/01_attempt/_02

# %%
# df_i.iloc[0].to_dict()

# %%
# "rclone copy $rclone_gdrive_stanford:norskov_research_storage/00_projects/PROJ_irox_oer/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/nersc/b19q9p6k72/101/01_attempt/_02 $PROJ_irox_oer/dft_workflow/run_slabs/run_o_covered/out_data/dft_jobs/b19q9p6k72/101/01_attempt/_02"

# # $rclone_gdrive_stanford
# # raul_gdrive_stanford

# %%
# df_i = df[df.is_submitted == False]

# grouped = df_i.groupby(["compenv", ])
# for name, group in grouped:
#     tmp = 42

#     print(40 * "=")
#     print(name)
#     print(40 * "=")
#     for name_i, row_i in group.iterrows():
#         # row_i = group.iloc[0]

#         # #########################################################
#         path_job_root_w_att_rev = row_i.path_job_root_w_att_rev
#         # #########################################################

#         # #########################################################
#         # Constructing path on cluster (remove cluster from path)
#         clust_path_list = []
#         for i in path_job_root_w_att_rev.split("/"):
#             clusters_list = ["nersc", "sherlock", "slac", ]

#             if i not in clusters_list:
#                 clust_path_list.append(i)

#         clust_path = "/".join(clust_path_list)

#         # #########################################################
#         # Constructing Rclone command
#         rclone_comm = "" + \
#             "rclone copy " + \
#             "$rclone_gdrive_stanford:norskov_research_storage/00_projects/PROJ_irox_oer/" + \
#             path_job_root_w_att_rev + \
#             " " + \
#             "$PROJ_irox_oer/" + \
#             clust_path + \
#             ""

#         print(rclone_comm)
#     print("")

# %%
# row_i = df.iloc[0]

# cand_clusters = []
# clusters_list = ["nersc", "sherlock", "slac", ]
# for i in row_i.path_job_root.split("/"):
#     if i in clusters_list:
#         cand_clusters.append(i)

# if len(cand_clusters) == 1:
#     cluster_i = cand_clusters[0]
# else:
#     print("Couldn't parse cluster from path")
#     print(cand_clusters)

# cluster_i
