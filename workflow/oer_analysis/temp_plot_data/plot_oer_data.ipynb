# %% [markdown]
# # Import Modules

# %%
import os
print(os.getcwd())
import sys

# %%
from methods import get_df_ads

df_ads = get_df_ads()

# df_ads_tmp.head()

# %%
df_ads
# Out:
#      compenv      slab_id  active_site       g_o  g_oh     job_id_o job_id_oh
# 0      nersc  fosurufu_23         45.0  4.064136  None  winivufu_21      None
# 1      nersc  galopuba_86         21.0  3.273659  None  vupihona_68      None
# 2      nersc  hadogato_47         84.0  4.186781  None  fonobiwu_65      None
# 3      nersc  hadogato_47         86.0  3.503503  None  fonobiwu_65      None
# 4      nersc  hadogato_47         87.0  3.697038  None  fonobiwu_65      None
# 5      nersc  hadogato_47         88.0  4.215389  None  fonobiwu_65      None
# 6      nersc  hogohuge_61         84.0  2.712188  None  betaloto_93      None
# 7      nersc  hogohuge_61         85.0  2.610016  None  betaloto_93      None
# 8      nersc  kalisule_45         62.0  2.654639  None  soneradi_76      None
# 9      nersc  kalisule_45         71.0  2.678612  None  soneradi_76      None
# 10     nersc  mubolemu_18         89.0  2.621733  None  hukasewa_36      None
# ...
